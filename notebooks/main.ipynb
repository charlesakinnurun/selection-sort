# %%
import time

# %%
def selection_sort(arr):
    # Selection Sort Algorithm
    # The Algorithm divides the input list into two parts
    # 1. A sorted sublist of items which is built up from the left to right
    # 2. A sublist of the remaining unsorted items

    # It works by repeatedly finding the minimum element from the unsorted part
    # and putting it at the beginning


    n = len(arr)

    # Traverse through all array elements
    # We loop up to n-1 because the last element will naturally be sorted
    for i in range(n):
        # Assume the current position is i is the minimum
        min_idx = i

        # Visualize the start of a new pass
        print(f"----- Pass {i +1}-----")
        print(f"Current state: {arr}")
        print(f"Scanning for the smallest element starting from index {i} (value: {arr[i]})")


        # Traverse the unsorted part of the array to find the actual minimum
        for j in range(i + 1, n):
            # Comparison: Is the element at j smaller than our current minimum
            if arr[j] < arr[min_idx]:
                # Update min_idx if a smaller element is found
                min_idx = j
                print(f"New minimum found: {arr[min_idx]} at index {j}")

        # Swap the found minimum element with first element of the unsorted part
        # Only swap if the minimum is not alreay at the current position i
        if min_idx != 1:
            print(f"Swapping index {i} ({arr[i]}) with index {min_idx} ({arr[min_idx]})")
            arr[i], arr[min_idx] = arr[min_idx], arr[i]
        else:
            print(f"Index {i} is alredy the minimum for this pass. No swap needed")

        # Show visualization of the current array state
        visualize_array(arr,i)

    return arr

# %%
def visualize_array(arr, sorted_up_to):
    # Creates a bar-chart style visualization in the console
    # "#" represents an element's value
    # "|" marks the boundary of the sorted portion

    print("Visualization")
    max_val = max(arr) if arr else 0
    for val in arr:
        bar = "#" * val
        print(f"{val:2}: {bar}")

    # Print a divider to show what is sorted
    boundary = "---" * (sorted_up_to + 1)
    print(f"Sorted boundary: {boundary} | (elements to the left are sorted)")
    time.sleep(0.5) # Pause briefly for effect

# %%
def run_example():
    # Runs various test cases to demonstrate the algorithm

    print("==========================================")
    print("   SELECTION SORT PYTHON DEMONSTRATION    ")
    print("==========================================")

    # Example 1: Standard Unsorted List
    test_1 = [29,10,24,37,13]
    print("EXAMPLE 1: Standard List")
    print(f"Initial: {test_1}")
    result_1 = selection_sort(test_1)
    print(f"Final Sorted Result: {result_1}")

    # Illustration of Logic for a small set [5, 2, 8]
    # 1. Start: [5, 2, 8]. i=0. Min is 5. Compare with 2. New Min=2. Compare with 8. Swap 5 and 2.
    # 2. State: [2, 5, 8]. i=1. Min is 5. Compare with 8. No swap.
    # 3. State: [2, 5, 8]. i=2. Last element. Done.

    # Example 2: List with duplicates
    test_2 = [3,1,2,1,3]
    print("EXAMPLE 2: List with duplicates")
    result_2 = selection_sort(test_1)
    print(f"Final Sorted Result: {result_2}")

    # Example 3: Already sorted list
    test_3 = [1,2,3,4]
    print("EXAMPLE 3: Already Sorted List")
    result_3 = selection_sort(test_3)
    print(f"Final Sorted List: {result_3}")

# %%
if __name__ == "__main__":
    run_example()
# Out:
# ==========================================
#    SELECTION SORT PYTHON DEMONSTRATION
# ==========================================
# EXAMPLE 1: Standard List
# Initial: [29, 10, 24, 37, 13]
# ----- Pass 1-----
# Current state: [29, 10, 24, 37, 13]
# Scanning for the smallest element starting from index 0 (value: 29)
# New minimum found: 10 at index 1
# Index 0 is alredy the minimum for this pass. No swap needed
# Visualization
# 29: #############################
# 10: ##########
# 24: ########################
# 37: #####################################
# 13: #############
# Sorted boundary: --- | (elements to the left are sorted)
# ----- Pass 2-----
# Current state: [29, 10, 24, 37, 13]
# Scanning for the smallest element starting from index 1 (value: 10)
# Index 1 is alredy the minimum for this pass. No swap needed
# Visualization
# 29: #############################
# 10: ##########
# 24: ########################
# 37: #####################################
# 13: #############
# Sorted boundary: ------ | (elements to the left are sorted)
# ----- Pass 3-----
# Current state: [29, 10, 24, 37, 13]
# Scanning for the smallest element starting from index 2 (value: 24)
# New minimum found: 13 at index 4
# Swapping index 2 (24) with index 4 (13)
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 37: #####################################
# 24: ########################
# Sorted boundary: --------- | (elements to the left are sorted)
# ----- Pass 4-----
# Current state: [29, 10, 13, 37, 24]
# Scanning for the smallest element starting from index 3 (value: 37)
# New minimum found: 24 at index 4
# Swapping index 3 (37) with index 4 (24)
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 24: ########################
# 37: #####################################
# Sorted boundary: ------------ | (elements to the left are sorted)
# ----- Pass 5-----
# Current state: [29, 10, 13, 24, 37]
# Scanning for the smallest element starting from index 4 (value: 37)
# Swapping index 4 (37) with index 4 (37)
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 24: ########################
# 37: #####################################
# Sorted boundary: --------------- | (elements to the left are sorted)
# Final Sorted Result: [29, 10, 13, 24, 37]
# EXAMPLE 2: List with duplicates
# ----- Pass 1-----
# Current state: [29, 10, 13, 24, 37]
# Scanning for the smallest element starting from index 0 (value: 29)
# New minimum found: 10 at index 1
# Index 0 is alredy the minimum for this pass. No swap needed
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 24: ########################
# 37: #####################################
# Sorted boundary: --- | (elements to the left are sorted)
# ----- Pass 2-----
# Current state: [29, 10, 13, 24, 37]
# Scanning for the smallest element starting from index 1 (value: 10)
# Index 1 is alredy the minimum for this pass. No swap needed
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 24: ########################
# 37: #####################################
# Sorted boundary: ------ | (elements to the left are sorted)
# ----- Pass 3-----
# Current state: [29, 10, 13, 24, 37]
# Scanning for the smallest element starting from index 2 (value: 13)
# Swapping index 2 (13) with index 2 (13)
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 24: ########################
# 37: #####################################
# Sorted boundary: --------- | (elements to the left are sorted)
# ----- Pass 4-----
# Current state: [29, 10, 13, 24, 37]
# Scanning for the smallest element starting from index 3 (value: 24)
# Swapping index 3 (24) with index 3 (24)
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 24: ########################
# 37: #####################################
# Sorted boundary: ------------ | (elements to the left are sorted)
# ----- Pass 5-----
# Current state: [29, 10, 13, 24, 37]
# Scanning for the smallest element starting from index 4 (value: 37)
# Swapping index 4 (37) with index 4 (37)
# Visualization
# 29: #############################
# 10: ##########
# 13: #############
# 24: ########################
# 37: #####################################
# Sorted boundary: --------------- | (elements to the left are sorted)
# Final Sorted Result: [29, 10, 13, 24, 37]
# EXAMPLE 3: Already Sorted List
# ----- Pass 1-----
# Current state: [1, 2, 3, 4]
# Scanning for the smallest element starting from index 0 (value: 1)
# Swapping index 0 (1) with index 0 (1)
# Visualization
#  1: #
#  2: ##
#  3: ###
#  4: ####
# Sorted boundary: --- | (elements to the left are sorted)
# ----- Pass 2-----
# Current state: [1, 2, 3, 4]
# Scanning for the smallest element starting from index 1 (value: 2)
# Index 1 is alredy the minimum for this pass. No swap needed
# Visualization
#  1: #
#  2: ##
#  3: ###
#  4: ####
# Sorted boundary: ------ | (elements to the left are sorted)
# ----- Pass 3-----
# Current state: [1, 2, 3, 4]
# Scanning for the smallest element starting from index 2 (value: 3)
# Swapping index 2 (3) with index 2 (3)
# Visualization
#  1: #
#  2: ##
#  3: ###
#  4: ####
# Sorted boundary: --------- | (elements to the left are sorted)
# ----- Pass 4-----
# Current state: [1, 2, 3, 4]
# Scanning for the smallest element starting from index 3 (value: 4)
# Swapping index 3 (4) with index 3 (4)
# Visualization
#  1: #
#  2: ##
#  3: ###
#  4: ####
# Sorted boundary: ------------ | (elements to the left are sorted)
# Final Sorted List: [1, 2, 3, 4]
